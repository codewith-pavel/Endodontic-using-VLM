# %%
from PIL import Image
import torchvision.transforms as transforms
import os

# %%
import random
from PIL import Image
import torchvision.transforms as transforms

# Define multiple transformations for maximum augmentation
def get_augmentation_transforms():
    return [
        transforms.Compose([
            transforms.Resize((300, 300)),
            transforms.RandomHorizontalFlip(p=1),  # Horizontal flip
            transforms.RandomVerticalFlip(p=1), # Vertical flip
            transforms.RandomRotation(degrees=random.randint(0, 90)),  # Random rotation up to 90 degrees
        ])
    ]

# Function to apply multiple transformations and save each augmented image
def augment_image(image_path, output_dir, max_augmentations=3):
    image = Image.open(image_path)
    augmentations = get_augmentation_transforms()
    
    for i in range(max_augmentations):
        for j, transform in enumerate(augmentations):
            # Apply the transformation
            augmented_image = transform(image)
            
            # Define output path with unique naming
            output_path = os.path.join(output_dir, f"{os.path.splitext(os.path.basename(image_path))[0]}_aug_{i}_{j}.jpg")
            
            # Save the augmented image
            augmented_image.save(output_path)
            print(f"Saved augmented image to {output_path}")

# %%
import os

# Define input and output directories
input_dir = '/kaggle/input/d/mahirafser/llava-inference/root-canal-captioning/train'  # Replace with your input image directory
output_dir = '/kaggle/working/augmented/train'  # Replace with the output directory for augmented images

# Ensure the output directory exists
os.makedirs(output_dir, exist_ok=True)

# Loop through images in the input directory
for filename in os.listdir(input_dir):
    if filename.endswith('.jpg') or filename.endswith('.png'):  # Modify if you have different formats
        image_path = os.path.join(input_dir, filename)
        
        # Apply multiple augmentations and save them
        augment_image(image_path, output_dir, 2)  # Pass the output directory directly
        
        #print(f"Augmented images saved for {filename}")
# Out:
# Saved augmented image to /kaggle/working/augmented/train/IS20230605_180809_4062_79958091_jpg.rf.11ec67fceabce339c96d01a265740532_aug_0_0.jpg
# Saved augmented image to /kaggle/working/augmented/train/IS20230605_180809_4062_79958091_jpg.rf.11ec67fceabce339c96d01a265740532_aug_1_0.jpg
# Saved augmented image to /kaggle/working/augmented/train/IS20231019_171740_5287_76281208_jpg.rf.7bea7a2e128414a8fa5fb8a09d0fa419_aug_0_0.jpg
# Saved augmented image to /kaggle/working/augmented/train/IS20231019_171740_5287_76281208_jpg.rf.7bea7a2e128414a8fa5fb8a09d0fa419_aug_1_0.jpg
# Saved augmented image to /kaggle/working/augmented/train/SeriesThumb_2c66799c-790c-41b8-9cdf-b70c72582a20_000001156_jpg.rf.27168fd85177da9fa5c92342e3dbce5d_aug_0_0.jpg
# Saved augmented image to /kaggle/working/augmented/train/SeriesThumb_2c66799c-790c-41b8-9cdf-b70c72582a20_000001156_jpg.rf.27168fd85177da9fa5c92342e3dbce5d_aug_1_0.jpg
# Saved augmented image to /kaggle/working/augmented/train/SeriesThumb_049ae54b-2d86-41bf-99f8-038bcda78761_000001960_jpg.rf.43ec9ae420503acce5cabe6865caa89f_aug_0_0.jpg
# Saved augmented image to /kaggle/working/augmented/train/SeriesThumb_049ae54b-2d86-41bf-99f8-038bcda78761_000001960_jpg.rf.43ec9ae420503acce5cabe6865caa89f_aug_1_0.jpg
# Saved augmented image to /kaggle/working/augmented/train/SeriesThumb_09c5f53c-6be3-4255-86fc-6b1b5918ff30_000000594_jpg.rf.59af13228a41e6483362c488c680de69_aug_0_0.jpg
# Saved augmented image to /kaggle/working/augmented/train/SeriesThumb_09c5f53c-6be3-4255-86fc-6b1b5918ff30_000000594_jpg.rf.59af13228a41e6483362c488c680de69_aug_1_0.jpg
# Saved augmented image to /kaggle/working/augmented/train/SeriesThumb_252631e2-295d-4a04-a4ef-dda5ba88ff7b_000002422_jpg.rf.a581b93151ae98640363922e2e1496bd_aug_0_0.jpg
# Saved augmented image to /kaggle/working/augmented/train/SeriesThumb_252631e2-295d-4a04-a4ef-dda5ba88ff7b_000002422_jpg.rf.a581b93151ae98640363922e2e1496bd_aug_1_0.jpg
# Saved augmented image to /kaggle/working/augmented/train/SeriesThumb_205d67ba-c62c-4275-9e6b-6b28ce586e14_000000682_jpg.rf.77a6e9510de29ccf0247e9c1f16a5fe2_aug_0_0.jpg
# Saved augmented image to /kaggle/working/augmented/train/SeriesThumb_205d67ba-c62c-4275-9e6b-6b28ce586e14_000000682_jpg.rf.77a6e9510de29ccf0247e9c1f16a5fe2_aug_1_0.jpg
# Saved augmented image to /kaggle/working/augmented/train/WhatsApp-Image-2024-04-03-at-21-55-52_8962a649_jpg.rf.2fb397c892bd0c92fb7a5e453ed6477b_aug_0_0.jpg
# Saved augmented image to /kaggle/working/augmented/train/WhatsApp-Image-2024-04-03-at-21-55-52
aug_0_0.jpg
# Saved augmented image to /kaggle/working/augmented/test/SeriesThumb_111e8bdd-926c-407c-8e3a-0b4e9c4d7ff5_000000958_jpg.rf.0f840a1690d7ce9badb67ecc6bb458ed_aug_1_0.jpg
# Saved augmented image to /kaggle/working/augmented/test/SeriesThumb_f9bef4df-237f-4bdd-857c-17b3fb2a7d9b_000000984_jpg.rf.f983cc8d7a2d69fa6965b18d91a5d0f5_aug_0_0.jpg
# Saved augmented image to /kaggle/working/augmented/test/SeriesThumb_f9bef4df-237f-4bdd-857c-17b3fb2a7d9b_000000984_jpg.rf.f983cc8d7a2d69fa6965b18d91a5d0f5_aug_1_0.jpg
# Saved augmented image to /kaggle/working/augmented/test/SeriesThumb_e4dbd91d-ac8c-4b53-843a-af46784be01f_000001606_jpg.rf.767f4c1cbd45b2424841365b9bda23a2_aug_0_0.jpg
# Saved augmented image to /kaggle/working/augmented/test/SeriesThumb_e4dbd91d-ac8c-4b53-843a-af46784be01f_000001606_jpg.rf.767f4c1cbd45b2424841365b9bda23a2_aug_1_0.jpg
# Saved augmented image to /kaggle/working/augmented/test/SeriesThumb_3b5acfa5-8deb-4d28-b062-c060dec9acda_000002124_jpg.rf.d3e0a8f77c62ed63a58a31c4ab237140_aug_0_0.jpg
# Saved augmented image to /kaggle/working/augmented/test/SeriesThumb_3b5acfa5-8deb-4d28-b062-c060dec9acda_000002124_jpg.rf.d3e0a8f77c62ed63a58a31c4ab237140_aug_1_0.jpg
# Saved augmented image to /kaggle/working/augmented/test/SeriesThumb_baaff31f-9c83-4d0b-bf41-f2681e12bd50_000001226_jpg.rf.38150ebc80b96a168a78d7202ac5d7b9_aug_0_0.jpg
# Saved augmented image to /kaggle/working/augmented/test/SeriesThumb_baaff31f-9c83-4d0b-bf41-f2681e12bd50_000001226_jpg.rf.38150ebc80b96a168a78d7202ac5d7b9_aug_1_0.jpg
# Saved augmented image to /kaggle/working/augmented/test/SeriesThumb_d62f6338-39b8-47ea-be50-e3cd2910201d_000001028_jpg.rf.8a6df3503beabc207c6e9f602eb7b609_aug_0_0.jpg
# Saved augmented image to /kaggle/working/augmented/test/SeriesThumb_d62f6338-39b8-47ea-be50-e3cd2910201d_000001028_jpg.rf.8a6df3503beabc207c6e9f602eb7b609_aug_1_0.jpg
# Saved augmented image to /kaggle/working/augmented/test/SeriesThumb_5b54c75f-0f77-427c-a6cc-ffe2746f3499_000000856_jpg.rf.5ec94920dbbe8b93404c85aed88143c3_aug_0_0.jpg
# Saved augmented image to /kaggle/working/augmented/test/SeriesThumb_5b54c75f-0f77-427c-a6cc-ffe2746f3499_000000856_jpg.rf.5ec94920dbbe8b93404c85aed88143c3_aug_1_0.jpg
# Saved augmented image to /kaggle/working/augmented/test/SeriesThumb_d472f356-f070-48de-adbf-1ad676665573_000001574_jpg.rf.cf1dd6c0e7ae802dfa6f225f752f5a1f_aug_0_0.jpg
# Saved augmented image to /kaggle/working/augmented/test/SeriesThumb_d472f356-f070-48de-adbf-1ad676665573_000001574_jpg.rf.cf1dd6c0e7ae802dfa6f225f752f5a1f_aug_1_0.jpg
# Saved augmented image to /kaggle/working/augmented/test/SeriesThumb_9e6ee67e-3c1c-4072-97c4-c26b886d2643_000000438_jpg.rf.37569bb0392d2473fc6d694e2881a474_aug_0_0.jpg
# Saved augmented image to /kaggle/working/augmented/test/SeriesThumb_9e6ee67e-3c1c-4072-97c4-c26b886d2643_000000438_jpg.rf.37569bb0392d2473fc6d694e2881a474_aug_1_0.jpg
# Saved augmented image to /kaggle/working/augmented/test/SeriesThumb_ab9d93a5-15ac-472c-8dbc-5e9593f6a92e_000002576_jpg.rf.15efcfea5f71cade5b59bad6f856cac9_aug_0_0.jpg
# Saved augmented image to /kaggle/working/augmented/test/SeriesThumb_ab9d93a5-15ac-472c-8dbc-5e9593f6a92e_000002576_jpg.rf.15efcfea5f71cade5b59bad6f856cac9_aug_1_0.jpg

# %% [markdown]
# # Baseline

# %%
# !pip install -q -U transformers
# !pip install -q accelerate
# !pip install -q -U accelerate
# !pip install -q trl
# !pip install -q peft
# !pip install -q bitsandbytes

# %%
from transformers import BitsAndBytesConfig
import torch
from transformers import AutoProcessor, AutoModelForImageTextToText

quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_compute_dtype=torch.float16,  # Reduce compute to half precision for speed/memory
    bnb_4bit_use_double_quant=True,  # Apply double quantization for further compression
    bnb_4bit_quant_type="nf4",  # Use non-negative matrix factorization (NF4) for better accuracy
)

# Model ID for Llava
model_id = "llava-hf/llava-1.5-13b-hf"

# Load the processor and model with the new configuration
processor = AutoProcessor.from_pretrained(model_id)
model = AutoModelForImageTextToText.from_pretrained(
    model_id,
    quantization_config=quantization_config,
    device_map="auto"
)
# Out:
# preprocessor_config.json:   0%|          | 0.00/505 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.36k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/41.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/552 [00:00<?, ?B/s]
# chat_template.json:   0%|          | 0.00/700 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.10k [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/77.2k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/6 [00:00<?, ?it/s]
# model-00001-of-00006.safetensors:   0%|          | 0.00/4.96G [00:00<?, ?B/s]
# model-00002-of-00006.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00003-of-00006.safetensors:   0%|          | 0.00/4.88G [00:00<?, ?B/s]
# model-00004-of-00006.safetensors:   0%|          | 0.00/4.93G [00:00<?, ?B/s]
# model-00005-of-00006.safetensors:   0%|          | 0.00/4.93G [00:00<?, ?B/s]
# model-00006-of-00006.safetensors:   0%|          | 0.00/2.02G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/6 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/141 [00:00<?, ?B/s]

# %%
import os
import random
from PIL import Image
import matplotlib.pyplot as plt

# Define the path to the dataset directory
dataset_dir = '/kaggle/working/augmented/valid'  # Adjust this path based on your directory structure

# List all files in the dataset directory
all_files = os.listdir(dataset_dir)
# Filter out only image files (assuming they have common image extensions)
image_files = [f for f in all_files if f.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp'))]

# Randomly select 30 image files to display
sample_files = random.sample(image_files, 30)

# Create a 3x10 grid for displaying images
fig, axes = plt.subplots(3, 10, figsize=(20, 6))
axes = axes.flatten()  # Flatten the array of axes for easy iteration

# Load and display the images
for i, file_name in enumerate(sample_files):
    image_path = os.path.join(dataset_dir, file_name)
    image = Image.open(image_path)

    # Plot the image
    axes[i].imshow(image)
    axes[i].axis('off')

# Hide any remaining empty subplots (in case there are fewer than 30 images)
for j in range(len(sample_files), len(axes)):
    axes[j].axis('off')

# Add a big title to the entire grid
fig.suptitle("Sample Images", fontsize=20)

plt.tight_layout(rect=[0, 0, 1, 0.95])  # Adjust layout to make room for the title
plt.show()

# %%
import os
from PIL import Image
import torch
from transformers import AutoProcessor

# Define the path to the dataset directory
dataset_dir = '/kaggle/working/augmented/valid'  # Adjust this path based on your directory structure

# List all files in the dataset directory
all_files = os.listdir(dataset_dir)
# Filter out only image files (assuming they have common image extensions)
image_files = [f for f in all_files if f.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp'))]

# Load all images
images = []
for file_name in image_files:
    image_path = os.path.join(dataset_dir, file_name)
    image = Image.open(image_path)
    images.append(image)

# Define the prompts
prompts = [ """ USER:  Analyze the root canal treatment status across various 
sections of the image, identifying whether each area is complete, incomplete, or 
in need of further intervention. Use concise descriptions to convey the overall 
treatment status effectively, limiting it to 2-3 sentences.\nASSISTANT: """
] * len(images)  # Replicate the prompt for each image

# Process all images with the prompts
inputs = processor(text=prompts, images=images, padding=True, return_tensors="pt").to("cuda")

# Print the shapes of the input tensors
for k, v in inputs.items():
    print(k, v.shape)
# Out:
# Expanding inputs for image tokens in LLaVa should be done in processing. Please add `patch_size` and `vision_feature_select_strategy` to the model's processing config or set directly with `processor.patch_size = {{patch_size}}` and processor.vision_feature_select_strategy = {{vision_feature_select_strategy}}`. Using processors without these attributes in the config is deprecated and will throw an error in v4.47.
# input_ids torch.Size([278, 78])
# attention_mask torch.Size([278, 78])
# pixel_values torch.Size([278, 3, 336, 336])

# %%
"""from transformers import pipeline
# Create an image-to-text pipeline with quantization configuration
pipe = pipeline(
    "image-to-text",
    model=model_id,
    model_kwargs={"quantization_config": quantization_config}
)"""
# Out:
# 'from transformers import pipeline\n# Create an image-to-text pipeline with quantization configuration\npipe = pipeline(\n    "image-to-text",\n    model=model_id,\n    model_kwargs={"quantization_config": quantization_config}\n)'

# %%
"""max_new_tokens = 200
prompt = "USER: \nDescribe the status of root canal treatment in various areas with a single sentence, indicating whether each area is complete, incomplete, or requires further treatment.\nASSISTANT:"

# Process all images with the prompts using the pipeline
results = []
for image in images:
    output = pipe(image, prompt=prompt, generate_kwargs={"max_new_tokens": 200})
    results.append(output[0]["generated_text"])

# Print the results
for result in results:
    print(result.split("ASSISTANT:")[-1].strip())"""
# Out:
# 'max_new_tokens = 200\nprompt = "USER: \nDescribe the status of root canal treatment in various areas with a single sentence, indicating whether each area is complete, incomplete, or requires further treatment.\nASSISTANT:"\n\n# Process all images with the prompts using the pipeline\nresults = []\nfor image in images:\n    output = pipe(image, prompt=prompt, generate_kwargs={"max_new_tokens": 200})\n    results.append(output[0]["generated_text"])\n\n# Print the results\nfor result in results:\n    print(result.split("ASSISTANT:")[-1].strip())'

# %%
from transformers import AutoProcessor, pipeline, BitsAndBytesConfig
# Create an image-to-text pipeline with quantization configuration
pipe = pipeline(
    "image-to-text",
    model=model_id,
    model_kwargs={"quantization_config": quantization_config}
)
# Out:
# `low_cpu_mem_usage` was None, now default to True since model is quantized.
# Loading checkpoint shards:   0%|          | 0/6 [00:00<?, ?it/s]

# %%
import os
import json
from PIL import Image
import torch
from transformers import AutoProcessor, pipeline, BitsAndBytesConfig
import matplotlib.pyplot as plt

# Define the path to the dataset directory and output file
dataset_dir = '/kaggle/working/augmented/train'  # Adjust this path based on your directory structure
output_jsonl = '/kaggle/working/augmented/train/train.jsonl'

# List all files in the dataset directory
all_files = os.listdir(dataset_dir)
# Filter out only image files (assuming they have common image extensions)
image_files = [f for f in all_files if f.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp'))]

# Load and resize all images
images = []
max_size = (300, 300)  # Maximum size (width, height) for resizing

for file_name in image_files:
    image_path = os.path.join(dataset_dir, file_name)
    image = Image.open(image_path)
    image.thumbnail(max_size)  # Resize image to fit within max_size
    images.append((file_name, image))  # Store image name and image

# Define the prompt
prompt =  """ USER:  Analyze the root canal treatment status across various 
sections of the image, identifying whether each area is complete, incomplete, or 
in need of further intervention. Use concise descriptions to convey the overall 
treatment status effectively, limiting it to 2-3 sentences.\nASSISTANT: """

# Process all images with the prompts using the pipeline
results = []
for file_name, image in images:
    output = pipe(image, prompt=prompt, generate_kwargs={"max_new_tokens": 200})
    caption = output[0]["generated_text"].split("ASSISTANT:")[-1].strip()
    results.append((file_name, caption))

# Write the results to a JSONL file
with open(output_jsonl, 'w') as f:
    for file_name, caption in results:
        # Write the JSON line in the required format
        entry = {
            "image": file_name,
            "prefix": "",
            "suffix": caption
        }
        f.write(json.dumps(entry) + '\n')  # Write each dictionary as a JSONL line

print(f"Captions saved to {output_jsonl}")
# Out:
# Expanding inputs for image tokens in LLaVa should be done in processing. Please add `patch_size` and `vision_feature_select_strategy` to the model's processing config or set directly with `processor.patch_size = {{patch_size}}` and processor.vision_feature_select_strategy = {{vision_feature_select_strategy}}`. Using processors without these attributes in the config is deprecated and will throw an error in v4.47.
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Captions saved to /kaggle/working/augmented/train/train.jsonl

# %%
import os
import json
from PIL import Image
import torch
from transformers import AutoProcessor, pipeline, BitsAndBytesConfig
import matplotlib.pyplot as plt

# Define the path to the dataset directory and output file
dataset_dir = '/kaggle/working/augmented/valid'  # Adjust this path based on your directory structure
output_jsonl = '/kaggle/working/augmented/valid/valid.jsonl'

# List all files in the dataset directory
all_files = os.listdir(dataset_dir)
# Filter out only image files (assuming they have common image extensions)
image_files = [f for f in all_files if f.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp'))]

# Load and resize all images
images = []
max_size = (300, 300)  # Maximum size (width, height) for resizing

for file_name in image_files:
    image_path = os.path.join(dataset_dir, file_name)
    image = Image.open(image_path)
    image.thumbnail(max_size)  # Resize image to fit within max_size
    images.append((file_name, image))  # Store image name and image

# Define the prompt
prompt =  """ USER:  Analyze the root canal treatment status across various 
sections of the image, identifying whether each area is complete, incomplete, or 
in need of further intervention. Use concise descriptions to convey the overall 
treatment status effectively, limiting it to 2-3 sentences.\nASSISTANT: """
# Process all images with the prompts using the pipeline
results = []
for file_name, image in images:
    output = pipe(image, prompt=prompt, generate_kwargs={"max_new_tokens": 200})
    caption = output[0]["generated_text"].split("ASSISTANT:")[-1].strip()
    results.append((file_name, caption))

# Write the results to a JSONL file
with open(output_jsonl, 'w') as f:
    for file_name, caption in results:
        # Write the JSON line in the required format
        entry = {
            "image": file_name,
            "prefix": "",
            "suffix": caption
        }
        f.write(json.dumps(entry) + '\n')  # Write each dictionary as a JSONL line

print(f"Captions saved to {output_jsonl}")
# Out:
# Captions saved to /kaggle/working/augmented/valid/valid.jsonl

# %%
import os
import json
from PIL import Image
import torch
from transformers import AutoProcessor, pipeline, BitsAndBytesConfig
import matplotlib.pyplot as plt

# Define the path to the dataset directory and output file
dataset_dir = '/kaggle/working/augmented/test'  # Adjust this path based on your directory structure
output_jsonl = '/kaggle/working/augmented/test/test.jsonl'

# List all files in the dataset directory
all_files = os.listdir(dataset_dir)
# Filter out only image files (assuming they have common image extensions)
image_files = [f for f in all_files if f.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp'))]

# Load and resize all images
images = []
max_size = (300, 300)  # Maximum size (width, height) for resizing

for file_name in image_files:
    image_path = os.path.join(dataset_dir, file_name)
    image = Image.open(image_path)
    image.thumbnail(max_size)  # Resize image to fit within max_size
    images.append((file_name, image))  # Store image name and image

# Define the prompt
prompt =  """ USER:  Analyze the root canal treatment status across various 
sections of the image, identifying whether each area is complete, incomplete, or 
in need of further intervention. Use concise descriptions to convey the overall 
treatment status effectively, limiting it to 2-3 sentences.\nASSISTANT: """
# Process all images with the prompts using the pipeline
results = []
for file_name, image in images:
    output = pipe(image, prompt=prompt, generate_kwargs={"max_new_tokens": 200})
    caption = output[0]["generated_text"].split("ASSISTANT:")[-1].strip()
    results.append((file_name, caption))

# Write the results to a JSONL file
with open(output_jsonl, 'w') as f:
    for file_name, caption in results:
        # Write the JSON line in the required format
        entry = {
            "image": file_name,
            "prefix": "",
            "suffix": caption
        }
        f.write(json.dumps(entry) + '\n')  # Write each dictionary as a JSONL line

print(f"Captions saved to {output_jsonl}")
# Out:
# Captions saved to /kaggle/working/augmented/test/test.jsonl

# %%
import json
import re

# Path to the uploaded JSONL file
input_jsonl = '/kaggle/working/augmented/train/train.jsonl'
output_jsonl = '/kaggle/working/augmented/train/preprocessed_train.jsonl'

# Open the input file and prepare a list for cleaned entries
cleaned_entries = []

with open(input_jsonl, 'r') as file:
    for line in file:
        entry = json.loads(line)
        suffix = entry.get("suffix", "")
        if suffix:
            # Clean the suffix by removing unwanted characters, numbers, and extra spaces
            clean_suffix = re.sub(r'\d+[\.\,]*', '', suffix)  # Remove numbers like 1., 10., etc.
            clean_suffix = re.sub(r'\s+', ' ', clean_suffix).strip()  # Remove extra spaces and newlines
            entry["suffix"] = clean_suffix  # Update the entry with the cleaned suffix
            cleaned_entries.append(entry)

# Write the cleaned entries back to a new JSONL file
with open(output_jsonl, 'w') as f:
    for entry in cleaned_entries:
        f.write(json.dumps(entry) + '\n')  # Write each cleaned entry as a JSONL line

print(f"Cleaned JSONL file saved to {output_jsonl}")
# Out:
# Cleaned JSONL file saved to /kaggle/working/augmented/train/preprocessed_train.jsonl

# %%
import json
import re

# Path to the uploaded JSONL file
input_jsonl = '/kaggle/working/augmented/valid/valid.jsonl'
output_jsonl = '/kaggle/working/augmented/valid/preprocessed_valid.jsonl'

# Open the input file and prepare a list for cleaned entries
cleaned_entries = []

with open(input_jsonl, 'r') as file:
    for line in file:
        entry = json.loads(line)
        suffix = entry.get("suffix", "")
        if suffix:
            # Clean the suffix by removing unwanted characters, numbers, and extra spaces
            clean_suffix = re.sub(r'\d+[\.\,]*', '', suffix)  # Remove numbers like 1., 10., etc.
            clean_suffix = re.sub(r'\s+', ' ', clean_suffix).strip()  # Remove extra spaces and newlines
            entry["suffix"] = clean_suffix  # Update the entry with the cleaned suffix
            cleaned_entries.append(entry)

# Write the cleaned entries back to a new JSONL file
with open(output_jsonl, 'w') as f:
    for entry in cleaned_entries:
        f.write(json.dumps(entry) + '\n')  # Write each cleaned entry as a JSONL line

print(f"Cleaned JSONL file saved to {output_jsonl}")
# Out:
# Cleaned JSONL file saved to /kaggle/working/augmented/valid/preprocessed_valid.jsonl

# %%
import json
import re

# Path to the uploaded JSONL file
input_jsonl = '/kaggle/working/augmented/test/test.jsonl'
output_jsonl = '/kaggle/working/augmented/test/preprocessed_test.jsonl'

# Open the input file and prepare a list for cleaned entries
cleaned_entries = []

with open(input_jsonl, 'r') as file:
    for line in file:
        entry = json.loads(line)
        suffix = entry.get("suffix", "")
        if suffix:
            # Clean the suffix by removing unwanted characters, numbers, and extra spaces
            clean_suffix = re.sub(r'\d+[\.\,]*', '', suffix)  # Remove numbers like 1., 10., etc.
            clean_suffix = re.sub(r'\s+', ' ', clean_suffix).strip()  # Remove extra spaces and newlines
            entry["suffix"] = clean_suffix  # Update the entry with the cleaned suffix
            cleaned_entries.append(entry)

# Write the cleaned entries back to a new JSONL file
with open(output_jsonl, 'w') as f:
    for entry in cleaned_entries:
        f.write(json.dumps(entry) + '\n')  # Write each cleaned entry as a JSONL line

print(f"Cleaned JSONL file saved to {output_jsonl}")
# Out:
# Cleaned JSONL file saved to /kaggle/working/augmented/test/preprocessed_test.jsonl

# %%
import shutil

# Define the directory to zip and the output zip file path
output_dir = '/kaggle/working/augmented'
zip_file_path = '/kaggle/working/augmented_dataset.zip'

# Zip the directory
shutil.make_archive('/kaggle/working/augmented_dataset', 'zip', output_dir)

# Download the zip file
from IPython.display import FileLink
FileLink(zip_file_path)
# Out:
# /kaggle/working/augmented_dataset.zip
